# %% [markdown]
# # Telecom's Churn Data Analysis :

# %% [markdown]
# #### Here, analyzed the dataset of an European Telecom Company.
# #### This Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer cancelled the subscription.
#
# #### Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention.

# %% [markdown]
# ## Business Understanding Of A Telecom Industry Customer Churn:
#
# Customer churn is a big problem in any industry and one of the most important concerns for the Telecom industry.
#
# The effect on the revenues of the companies, because of this customer churns is huge, especially in the telecom field, that's why these companies are seeking to develop a predictive potential customer churn.
#
# In this highly competitive market, the telecommunications industry experiences an average of 15-25% annual churn rate, and it costs 5-10 times more to acquire a new customer than to retain an existing one, that's why customer retention has now become even more important than customer acquisition.
#
# Therefore, finding those factors that increase customer churn is important to take necessary actions to reduce this churn.
#
# ##### The main goal of the project is to develop an understanding of the cause of customer churn which assists telecom operators to predict customers who are most likely subject to churn, and what to do to retain the most valuable customer.

# %% [markdown]
# ## Import Libraries :

# %%
import pandas as pd                      # To import pandas library
import seaborn as sns                    # To import seaborn library
import matplotlib.pyplot as py           # To import matplotlib library
# %matplotlib inline   
                                         # It is use to show plots and graphs without writing py.show()
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import Dataset :

# %%
data = pd.read_csv(r"E:\c drive\Desktop\CloudyML\Resume Data Analytics Projects\Data Science Lovers Project\Resume Project\Telecom.csv")

# Use pd.read_csv() because dataset is in csv format

# %% [markdown]
# ## Exploring the dataset :

# %%
data
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# #### head ()

# %%
data.head()   # It will show top 5 records of the dataset
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# #### tail ()

# %%
data.tail()   # It will show last 5 records of the dataset
# Out:
#      state  account length  area code phone number international plan  \
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 3328             yes                     36              156.2
# 3329              no                      0              231.1
# 3330              no                      0              180.8
# 3331              no                      0              213.8
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 3328               77             26.55  ...              126
# ...

# %% [markdown]
# #### info ()

# %%
data.info()    # It show columns count,data types, memory,index and not null count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %% [markdown]
# #### shape

# %%
data.shape   # It shows the number of rows and columns
# Out:
# (3333, 21)

# %% [markdown]
# #### nunique ()

# %%
data.nunique()  # It shows the number of unique values in each column
# Out:
# state                       51
# account length             212
# area code                    3
# phone number              3333
# international plan           2
# voice mail plan              2
# number vmail messages       46
# total day minutes         1667
# total day calls            119
# total day charge          1667
# total eve minutes         1611
# total eve calls            123
# total eve charge          1440
# total night minutes       1591
# total night calls          120
# total night charge         933
# total intl minutes         162
# total intl calls            21
# total intl charge          162
# customer service calls      10
# churn                        2
# dtype: int64

# %% [markdown]
# #### columns

# %%
data.columns    # It shows the total columns in dataframe
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %% [markdown]
# #### dtypes

# %%
data.dtypes   # It shows the data type for each column
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan         object
# voice mail plan            object
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        bool
# dtype: object

# %% [markdown]
# #### describe ()

# %%
data.describe()              

# It gives the summary statistics of all numeric columns. It checks extreme outliers and large deviations etc.
# It shows the count of non-null values in each column, and mean,std,minimum,maximum,
# 25th,50th,75th percentile value of each column
# Percentile means - how many of the values are less than the given percentile
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
data.describe(include='object')       # It gives the summary of all categorical columns
# It shows the count of non-null and unique values in each column, Top value with its occurance in each column
# Out:
#        state phone number international plan voice mail plan
# count   3333         3333               3333            3333
# unique    51         3333                  2               2
# top       WV     382-4657                 no              no
# freq     106            1               3010            2411

# %% [markdown]
# ## Checking missing and duplicate values :

# %%
data.head(2)   # To show the top 2 records of dataframe
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %% [markdown]
# #### isna ()

# %%
data.isna().sum()   # It shows the count of null values in each column
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %% [markdown]
# #### notnull ()

# %%
data.notnull().sum()  # It shows the count of all the not null values in each column
# Out:
# state                     3333
# account length            3333
# area code                 3333
# phone number              3333
# international plan        3333
# voice mail plan           3333
# number vmail messages     3333
# total day minutes         3333
# total day calls           3333
# total day charge          3333
# total eve minutes         3333
# total eve calls           3333
# total eve charge          3333
# total night minutes       3333
# total night calls         3333
# total night charge        3333
# total intl minutes        3333
# total intl calls          3333
# total intl charge         3333
# customer service calls    3333
# churn                     3333
# dtype: int64

# %%
data.notna().sum()
# Out:
# state                     3333
# account length            3333
# area code                 3333
# phone number              3333
# international plan        3333
# voice mail plan           3333
# number vmail messages     3333
# total day minutes         3333
# total day calls           3333
# total day charge          3333
# total eve minutes         3333
# total eve calls           3333
# total eve charge          3333
# total night minutes       3333
# total night calls         3333
# total night charge        3333
# total intl minutes        3333
# total intl calls          3333
# total intl charge         3333
# customer service calls    3333
# churn                     3333
# dtype: int64

# %% [markdown]
# #### duplicated ()

# %%
data[data.duplicated()]  # To show the duplicate values in the dataframe
                         # This dataframe has no duplicate values
# Out:
# Empty DataFrame
# Columns: [state, account length, area code, phone number, international plan, voice mail plan, number vmail messages, total day minutes, total day calls, total day charge, total eve minutes, total eve calls, total eve charge, total night minutes, total night calls, total night charge, total intl minutes, total intl calls, total intl charge, customer service calls, churn]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# #### drop_duplicates ()

# %%
data = data.drop_duplicates()   # To drop all the duplicate values from dataframe

data
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# ----

# %% [markdown]
# ----

# %% [markdown]
# -----

# %% [markdown]
# # 1) Analyzing the Churn Variable :

# %%
data.head(5)   # To show the top 5 records of the dataframe
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# #### unique ()

# %%
data["churn"].unique()   # To show the unique values present in column "Churn"
# Out:
# array([False,  True])

# %% [markdown]
# #### nunique ()

# %%
data["churn"].nunique()  # To show the count of unique values present in column "Churn"
# Out:
# 2

# %% [markdown]
# #### value_counts ()

# %%
data["churn"].value_counts()  # To show the count of unique values present in colun "Churn"
# Out:
# False    2850
# True      483
# Name: churn, dtype: int64

# %% [markdown]
# # Percentage of churn customers :

# %%
data.shape
# Out:
# (3333, 21)

# %%
str(483*100/3333) + " %"  # It shows the percentage of churned customers(True) in dataset
# Out:
# '14.491449144914492 %'

# %%
str(2850*100/3333) + " %"   # It shows the percentage of existing customers(False)
# Out:
# '85.5085508550855 %'

# %% [markdown]
# # Donut Chart ( Creating donut chart for Churn and Non - Churn Customers )

# %%
A = data["churn"].value_counts()
A
# Out:
# False    2850
# True      483
# Name: churn, dtype: int64

# %%
type(A)
# Out:
# pandas.core.series.Series

# %%
py.pie(A , labels = ["Not Churned" , "Churned"] , colors = ["orange" , "lime"] , startangle = 50 , radius  = 1.5,
      explode = [0,0.2], autopct = "%1.2f%%", pctdistance = 0.75)

circle = py.Circle((0,0) , 0.75, color = "white")
c = py.gcf()
c.gca().add_artist(circle)
py.title("Churned VS Non-Churned Custoomers")
py.show()

# Donut chart is a modified Pie chart, with an area from center cut out

#1 First, drawing a pie plot, using Matplotlib library
# The data is taken from the variable 'A' .... labels are given as 'Churned' & 'Not Churned' ...
# ... color is given to each label 'orange' & 'lime' ... startangle means the angle for slicing, set as 50 ...
# ... radius of the circle is set as 2 ... 
# ... explode is used to cut the slice out of the figure ... 
# ... autopct is used to show the % on the chart upto required decimal points ...
# ... pctdistance is given for distance of % from the center

#2 Second, using plt.Circle...we will create a circle and save it in the variable name 'circle' ...
# ... putting (0,0) by default ... 1 is radius of circle ... and color of circle is white
# plt.gcf() is used to get the current figure ... and we are saving it in variable 'c'

#3 Third, we will add the 'circle' at the center of pie chart ... using gca().add_artist()
# We have given the title to the chart using plt.title()
# plt.show() - To show the chart

# %% [markdown]
# # Countplot for Churned and Non - Churned Customers :

# %%
sns.countplot(data["churn"])
py.show()

# Drawing countplot for Churn variable using Seaborn Library

# %% [markdown]
# **Outcome**
# > After analyzing Churn column, we have noticed that almost 15% customers have churned.

# %% [markdown]
# # 2) Analyzing the State Variable :

# %%
data.head(2)    # To show top 2 records of dataset
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %% [markdown]
# ##### unique ()

# %%
data["state"].unique()   # To show  unique values present in State column
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %% [markdown]
# ##### nunique ()

# %%
data["state"].nunique()  # To show the count of unique values present in State column
# Out:
# 51

# %% [markdown]
# ##### value_counts ()

# %%
data["state"].value_counts()    # To show the count of all the unique state values
                                # By default, it shows the result in descending order
                                # To see the result in ascending order , data["state"].value_counts(ascending = True)
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# NC     68
# NJ     68
# MT     68
# CO     66
# NV     66
# WA     66
# RI     65
# MA     65
# MS     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ME     62
# ND     62
# NE     61
# OK     61
# DE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: state, dtype: int64

# %% [markdown]
# # Countplot :

# %%
py.figure(figsize = (20 , 7))

sns.countplot(data["state"])   # Drawing countplot for State column
py.xticks(fontsize = 12)       # Setting the fontsize of the states on x - axis
py.yticks(fontsize = 12)       # Setting the fontsize of the count on Y - axis
py.xlabel("States" , fontsize = 20 , color = "red")   # Setting the label on X - axis as State, its fontsize, its color
py.ylabel("Count" , fontsize = 20 , color = "green")  # Setting the label on Y - axis as Count, its fontsize, its color
py.show()

# The X-axis showing the States present in dataset and Y-axis showing their count(occurance) 
# i.e. how many times a state is present column

# %% [markdown]
# # Showing Churned and Non-Churned State-wise :

# %%
sns.set(style = "whitegrid")  # using seaborn library, setting the background of the figure as "whitegrid"
 
py.figure(figsize = (20,7))  # Setting the size of the figure 20 * 7, using matplotlib library

sns.countplot(data["state"] , hue = data["churn"])  

py.xlabel("States" , fontsize = 20 , color = "red") # Setting the label on X-axis as State , its fontsize, its color
py.ylabel("Count" , fontsize = 20 , color = "red")  # Setting the label on Y-axis as Count, its fontsize, its color
py.show()

# %%
data.head(2)  # To show the top 2 records from dataset
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %% [markdown]
# ###### groupby ()

# %%
a = data.groupby("state")["churn"].mean()*100

a.sort_values(ascending = False)

# Here, we will consider two columns while groupby
# Use groupby on State column, and showing the mean values of the churn w.r.t each state
# and multiplying the result by 100
# By default, it will consider True values from churn column to calculate mean
# Because, the data-type of Churn column is Boolean-Type..
# Out:
# state
# NJ    26.470588
# CA    26.470588
# TX    25.000000
# MD    24.285714
# SC    23.333333
# MI    21.917808
# MS    21.538462
# NV    21.212121
# WA    21.212121
# ME    20.967742
# MT    20.588235
# AR    20.000000
# KS    18.571429
# NY    18.072289
# MN    17.857143
# PA    17.777778
# MA    16.923077
# CT    16.216216
# NC    16.176471
# NH    16.071429
# GA    14.814815
# DE    14.754098
# OK    14.754098
# OR    14.102564
# UT    13.888889
# CO    13.636364
# KY    13.559322
# SD    13.333333
# OH    12.820513
# FL    12.698413
# IN    12.676056
# ID    12.328767
# WY    11.688312
# MO    11.111111
# VT    10.958904
# AL    10.000000
# NM     9.677419
# ND     9.677419
# WV     9.433962
# TN     9.433962
# DC     9.259259
# RI     9.230769
# WI     8.974359
# IL     8.620690
# NE     8.196721
# LA     7.843137
# IA     6.818182
# VA     6.493506
# AZ     6.250000
# AK     5.769231
# HI     5.660377
# Name: churn, dtype: float64

# %% [markdown]
# # Line Chart ( Drawing the line chart to show the state-wise churn rate ) :

# %%
# Drawing the line chart :

x = data["state"].unique()                     # Saving all the unique values of state column in variable in x
y = data.groupby("state")["churn"].mean()*100  # Using groupby on state, calculating mean of churn
                                               # mean value against each state and saving it in variable y
    
py.figure(figsize = (20,7))                # Seting the size of figure 20*7 using matplotlib library
sns.set(style = "darkgrid")                # Setting the figure background as "Darkgrid"

py.plot(x,y,color="black",marker = "*" , ms = 10)  # Plotting the line chart using x and y variable
                                                   # State showing on x-axis and mean showing on y-axis, marker set as "*"
                                                   # marker size set as 10
        
py.title("State Churn Graph", fontsize = 25, color = "Green") # Using matplotlib ,setting the title of the figur
py.xlabel("States", fontsize = 20, color = "red")   # Using matplotlib, setting x label, its fontsize, its color
py.ylabel("Churn Rate" , fontsize = 20 , color = "red") # Using matplotlib, setting y label, its fontsize, its color

py.show()

# %% [markdown]
# ## States with the highest Churn Rate :

# %%
data.groupby("state")["churn"].mean().sort_values(ascending = False).head(5)*100
# Out:
# state
# NJ    26.470588
# CA    26.470588
# TX    25.000000
# MD    24.285714
# SC    23.333333
# Name: churn, dtype: float64

# %%
data.head()   # To show the top 5 records from dataset
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# ## Calculating State VS Churn Percentage :

# %% [markdown]
# #### crosstab ()

# %%
c = pd.crosstab(data["state"] , data["churn"],margins= True)

c["Percentage_Churn"] = c[True] * 100/ c["All"]  
                                 # Using crosstab function from pandas library to compute a simple cross-tabulation...
                                 # ...of two columns i.e., 'state' & 'churn' and saving the output in varibale 'c'
                                 # ... margins=True means - to show the sum of both values in a new column 'All'
                                 # Creating a new column 'Percantage_Churn', which shows the
                                 # percentage of churn customers in each state
print(c)
print(type(c))
# Out:
# churn  False  True   All  Percentage_Churn
# state
# AK        49     3    52          5.769231
# AL        72     8    80         10.000000
# AR        44    11    55         20.000000
# AZ        60     4    64          6.250000
# CA        25     9    34         26.470588
# CO        57     9    66         13.636364
# CT        62    12    74         16.216216
# DC        49     5    54          9.259259
# DE        52     9    61         14.754098
# FL        55     8    63         12.698413
# GA        46     8    54         14.814815
# HI        50     3    53          5.660377
# IA        41     3    44          6.818182
# ID        64     9    73         12.328767
# IL        53     5    58          8.620690
# IN        62     9    71         12.676056
# KS        57    13    70         18.571429
# KY        51     8    59         13.559322
# LA        47     4    51          7.843137
# MA        54    11    65         16.923077
# MD        53    17    70         24.285714
# ...

# %% [markdown]
# ##### info ()

# %%
c.info()

# To show the basic information of the DataFrame 'c'
# It shows indexes, columns counts, each column name with its non-null values count & data-type and, memory of DataFrame
# Now, in this dataframe 'c', we have 4 columns 'False,True,All,Percentage_Churn' each having 52 non-null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, AK to All
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   False             52 non-null     int64
#  1   True              52 non-null     int64
#  2   All               52 non-null     int64
#  3   Percentage_Churn  52 non-null     float64
# dtypes: float64(1), int64(3)
# memory usage: 2.0+ KB

# %% [markdown]
# ##### sort ()

# %%
# Top 5 states with the highest churn rate

c.sort_values(by = "Percentage_Churn" , ascending = False).head(5)
# Out:
# churn  False  True  All  Percentage_Churn
# state
# CA        25     9   34         26.470588
# NJ        50    18   68         26.470588
# TX        54    18   72         25.000000
# MD        53    17   70         24.285714
# SC        46    14   60         23.333333

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 3) Analyzing the "Area Code" variable  :

# %%
data.head()   # To shpw the tp 5 records from dataset
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# ##### unique ()

# %%
data["area code"].unique()  # It shows the total unique values present in "Area Code"
# Out:
# array([415, 408, 510], dtype=int64)

# %% [markdown]
# ##### nunique ()

# %%
data["area code"].nunique()  # It shows the count of unique values present in "Area Code"
# Out:
# 3

# %% [markdown]
# ##### value_counts ()

# %%
data["area code"].value_counts()  # It shows the count / occurance of unique values present in "Area Code" column
# Out:
# 415    1655
# 510     840
# 408     838
# Name: area code, dtype: int64

# %% [markdown]
# ###### groupby ()

# %%
data.groupby("area code")["churn"].mean()*100

# Use groupby on "area code" column, and showing the mean values of churn w.r.t. each area code
# and multiplying the result by 100
# Out:
# area code
# 408    14.558473
# 415    14.259819
# 510    14.880952
# Name: churn, dtype: float64

# %% [markdown]
# ## Calculating Area Code Vs Churn Percentage :

# %% [markdown]
# ##### crosstab ()

# %%
d = pd.crosstab(data["area code"] , data["churn"] , margins = True)

                 # Using crosstab function from pandas library to compute a simple cross-tabulation of two columns 
                 # i.e., 'area code' & 'churn' and saving the output in varibale 'd'
                 # margins=True means - to show sum of both values in a new column 'All'

d["Percentage Churn"] = d[True] * 100 / d["All"]

print(d)
print(type(d))
# Out:
# churn      False  True   All  Percentage Churn
# area code
# 408          716   122   838         14.558473
# 415         1419   236  1655         14.259819
# 510          715   125   840         14.880952
# All         2850   483  3333         14.491449
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Drawing countplot to show "area code" wise churn rate :

# %% [markdown]
# #### countplot ()

# %%
py.figure(figsize = (14,5))  # Setting the figure size 14*5 using matplotlib library

sns.countplot(data =data , x = "area code" , hue = "churn", palette = "mako")
                            # Drawing the count plot for area code column
                            # hue = "churn" represents that we want to use churn for color encoding
                            # i.e. color the bar differently for churn and non-churn
py.title("Area-wise count of Churn", fontsize = 22, color = "orange")
py.xlabel("Area Code", fontsize = 12, color = "red")
py.ylabel("Count of Churn", fontsize = 12, color = "red")
py.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 4) Analyzing the "Account Length" column :

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# #### nunique ()

# %%
data["account length"].nunique()  # To show the unique value count present in "account length" column
# Out:
# 212

# %% [markdown]
# ### Creating dataframes :

# %%
# Creating tow dataframes one for churn and one for non churn 

churn = data[data["churn"] == True]
# creating a new dataframe "churn_data", in which we are considering all the records where churn is 'True'

non_churn = data[data["churn"] == False]
# creating a new dataframe "non_churn", in which we are considering all the records where churn is  "False"

# %%
churn
# Out:
#      state  account length  area code phone number international plan  \
# 10      IN              65        415     329-6603                 no
# 15      NY             161        415     351-7269                 no
# 21      CO              77        408     393-7984                 no
# 33      AZ              12        408     360-1596                 no
# 41      MD             135        408     383-6029                yes
# ...    ...             ...        ...          ...                ...
# 3301    CA              84        415     417-1488                 no
# 3304    IL              71        510     330-7137                yes
# 3320    GA             122        510     411-5677                yes
# 3322    MD              62        408     409-1856                 no
# 3323    IN             117        415     362-5899                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
non_churn
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# #### info ()

# %%
churn.info()

# To show the basic information about the dataframe "churn" 
# It shows indexes, columns counts, each column name with its non-null values count & data-type, and memory of DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 483 entries, 10 to 3323
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   483 non-null    object
#  1   account length          483 non-null    int64
#  2   area code               483 non-null    int64
#  3   phone number            483 non-null    object
#  4   international plan      483 non-null    object
#  5   voice mail plan         483 non-null    object
#  6   number vmail messages   483 non-null    int64
#  7   total day minutes       483 non-null    float64
#  8   total day calls         483 non-null    int64
#  9   total day charge        483 non-null    float64
#  10  total eve minutes       483 non-null    float64
#  11  total eve calls         483 non-null    int64
#  12  total eve charge        483 non-null    float64
#  13  total night minutes     483 non-null    float64
# ...

# %%
non_churn.info()

# To show the basic information about the dataframe "churn" 
# It shows indexes, columns counts, each column name with its non-null values count & data-type, and memory of DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2850 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   2850 non-null   object
#  1   account length          2850 non-null   int64
#  2   area code               2850 non-null   int64
#  3   phone number            2850 non-null   object
#  4   international plan      2850 non-null   object
#  5   voice mail plan         2850 non-null   object
#  6   number vmail messages   2850 non-null   int64
#  7   total day minutes       2850 non-null   float64
#  8   total day calls         2850 non-null   int64
#  9   total day charge        2850 non-null   float64
#  10  total eve minutes       2850 non-null   float64
#  11  total eve calls         2850 non-null   int64
#  12  total eve charge        2850 non-null   float64
#  13  total night minutes     2850 non-null   float64
# ...

# %% [markdown]
# #### shape ()

# %%
data.shape   # To show the number of rows and columns in dataframe
# Out:
# (3333, 21)

# %% [markdown]
# ## Distibution plot for "Account Length" :

# %%
# Creating distribution plot for account length column

py.figure(figsize=(15,5))
sns.distplot(data["account length"] , color = "orange")
py.xlabel("Account Length" , fontsize = 15)
py.ylabel("Density" , fontsize = 15)

py.show()


# The distplot shows a histogram with a line on it. It represents the distribution of a variable against the...
#...density distribution.
# Here, using Seaborn library we are plotting a distribution plot for the column 'account length'... 
# ...with 'orange' color.
# Using matplotlib, setting the label of x-axis as "Account Length", with fontsize of 15
# Using matplotlib, setting the label of x-axis as "Density", with fontsize of 15
# plt.show() - To show the plot

# %% [markdown]
# ## Comparing Account Length of 'churned' and 'not churned' customers, using distplot

# %%
py.figure(figsize = (15,7))

sns.distplot(data["account length"] , color = "grey")
# Using Seaborn library, we are plotting a distribution plot for the column 'account length' from original dataframe... 
# ...with 'grey' color ... and setting the label as 'All'

sns.distplot(churn["account length"] , hist = False, color = "red", label = "Churned")
# Using Seaborn library, we are plotting a distribution plot for the column 'account length' from 'churn'...
#...dataframe with 'red' color ... and setting the label as 'Churned'. Here, hist=False is given because...
#...we don't want to show a histogram for this, we want to show a line only

sns.distplot(non_churn["account length"] , hist = False , color = "yellow" , label = "Non-Churned")
# Using Seaborn library, we are plotting a distribution plot for the column 'account length' from 'non_churn'...
#...dataframe with 'yellow' color ... and setting the label as 'Not Churned'. Here, hist=False is given because...
#...we don't want to show a histogram for this, we want to show a line only

py.xlabel("Account length" , fontsize = 20)
# Using matplotlib, setting the label of x-axis as "Account Length", with fontsize of 20

py.ylabel("Density" , fontsize = 20)
# Using matplotlib, setting the label of y-axis as "Density", with fontsize of 20

py.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 5) Analyzing the "International Plan" column :

# %%
data.head()   # To show the top 5 records from dataset
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# #### unique ()

# %%
data["international plan"].unique()   # To show the unique values in internationl plan column
# Out:
# array(['no', 'yes'], dtype=object)

# %% [markdown]
# #### value_count ()

# %%
data["international plan"].value_counts()  # To show the count of all the unique value present in international plan column
# Out:
# no     3010
# yes     323
# Name: international plan, dtype: int64

# %% [markdown]
# ## Creating dataframe :

# %%
# Creating a new dataframe 'yes_int_plan',containing the records of those 
# Churned customers who were having international plan

# Here, we have used filtering with '&' operator, to select records satisfying two conditions - 
# 1. 'international plan' == 'yes'
# 2. 'churn' == 'True'

yes_int_plan = data[(data["international plan"] == "yes") & (data["churn"] == True)]

yes_int_plan

# it shows there are total 137 records satisfying these two conditions
# Out:
#      state  account length  area code phone number international plan  \
# 41      MD             135        408     383-6029                yes
# 115     ME              36        510     363-1069                yes
# 144     VT             117        408     390-2390                yes
# 198     ME             131        510     353-7292                yes
# 214     FL              70        510     366-6345                yes
# ...    ...             ...        ...          ...                ...
# 3246    NC              77        408     334-6129                yes
# 3255    RI             138        510     411-6823                yes
# 3291    MI             119        510     335-7324                yes
# 3304    IL              71        510     330-7137                yes
# 3320    GA             122        510     411-5677                yes
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
# Creating a new dataframe 'no_int_plan',containing the records of those 
# Churned customers who were not having international plan

# Here, we have used filtering with '&' operator, to select records satisfying two conditions - 
# 1. 'international plan' == 'no'
# 2. 'churn' == 'True'

no_int_plan = data[(data["international plan"] == "no") & (data["churn"] == True)]
no_int_plan

# it shows there are total 346 records satisfying these two conditions
# Out:
#      state  account length  area code phone number international plan  \
# 10      IN              65        415     329-6603                 no
# 15      NY             161        415     351-7269                 no
# 21      CO              77        408     393-7984                 no
# 33      AZ              12        408     360-1596                 no
# 48      ID             119        415     398-1294                 no
# ...    ...             ...        ...          ...                ...
# 3280    AR              76        408     345-3614                 no
# 3287    KS             170        415     404-5840                 no
# 3301    CA              84        415     417-1488                 no
# 3322    MD              62        408     409-1856                 no
# 3323    IN             117        415     362-5899                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# ## Percentage of churned customer using international plan :

# %%
# we noticed that 323 customers were using international plan, and 137 customers churned out of them
# means a churn percentage of 42.4

137/323*100
# Out:
# 42.414860681114554

# %%
# Total number of people having internationa plan is 323

data[data["international plan"]=="yes"]
# Out:
#      state  account length  area code phone number international plan  \
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# 5       AL             118        510     391-8027                yes
# 7       MO             147        415     329-9001                yes
# 9       WV             141        415     330-8173                yes
# ...    ...             ...        ...          ...                ...
# 3304    IL              71        510     330-7137                yes
# 3309    VT             100        408     340-9449                yes
# 3317    SD             163        415     379-7290                yes
# 3320    GA             122        510     411-5677                yes
# 3331    CT             184        510     364-6381                yes
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
# Total number of people having no international plan is 3010

data[data["international plan"] == "no"]
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 6       MA             121        510     355-9993                 no
# 8       LA             117        408     335-4719                 no
# ...    ...             ...        ...          ...                ...
# 3327    SC              79        415     348-3830                 no
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# ## Percentage of churned customer having no international plan

# %%
# we noticed that 3010 customers were not using international plan, and 346 customers churned out of them
# means a churn percentage of 11.4

346*100/3010
# Out:
# 11.49501661129568

# %% [markdown]
# #### crosstab ()

# %%
int_plan_data = pd.crosstab(data["international plan"] , data["churn"], margins = True)

int_plan_data

# Using crosstab function from pandas library to compute a simple cross-tabulation...
#...of two columns i.e., 'international plan' & 'churn' and saving the output in varibale 'int_plan_data'
# ... margins=True means - to show the sum of both values in a new column 'All'
# Out:
# churn               False  True   All
# international plan
# no                   2664   346  3010
# yes                   186   137   323
# All                  2850   483  3333

# %% [markdown]
# ### Creating new column "Churn Percentage" :

# %%
# Creating a new column 'churn percent'- to show the churn percentage of the customers who were using international plan

int_plan_data["Churn percentage"] = int_plan_data[True]*100/int_plan_data["All"]

int_plan_data
# Out:
# churn               False  True   All  Churn percentage
# international plan
# no                   2664   346  3010         11.495017
# yes                   186   137   323         42.414861
# All                  2850   483  3333         14.491449

# %% [markdown]
# #### info ()

# %%
int_plan_data.info()

# To show the basic information about the dataframe 'int_plan_data'
# It shows indexes, columns counts, each column name with its non-null values count & data-type, and memory of DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, no to All
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   False             3 non-null      int64
#  1   True              3 non-null      int64
#  2   All               3 non-null      int64
#  3   Churn percentage  3 non-null      float64
# dtypes: float64(1), int64(3)
# memory usage: 120.0+ bytes

# %% [markdown]
# #### value_counts ()

# %%
i = data["international plan"].value_counts()

i
# Out:
# no     3010
# yes     323
# Name: international plan, dtype: int64

# %% [markdown]
# ## Creating a Donut Chart of customers count 'having international plan' and 'not having international plan' :

# %%
py.pie(i , labels = ["NO" ,"YES"], colors = ["yellow","cyan"], startangle = 50 , radius = 1.5, explode = (0,0.2),
      autopct = "%1.2f%%", pctdistance = 0.75)

circle = py.Circle((0,0) , 0.75, color="white")

c = py.gcf()
c.gca().add_artist(circle)
py.title("Count of customer having Internationl Plan ", fontsize = 15)

py.show()


# Donut chart is a modified Pie chart, with an area from center cut out

#1 First, drawing a pie plot, using Matplotlib library
# The data is taken from the variable 'i' .... labels are given as 'No' & 'Yes' ...
# ... color is given to each label 'yellow' & 'cyan' ... startangle means the angle for slicing, set as 50 ...
#  radius of the circle is set as 1.5 ... 
# ... explode is used to cut the slice out of the figure ... 
# ... autopct is used to show the % on the chart upto required decimal points ...
# ... pctdistance is given for distance of % from the center

#2 Second, using plt.Circle...we will create a circle and save it in the variable name 'circle' ...
# ... putting (0,0) by default ... 0.75 is radius of circle ... and color of circle is 'white'
# plt.gcf() is used to get the current figure ... and we are saving it in variable 'c'

#3 Third, we will add the 'circle' at the center of pie chart ... using gca().add_artist()
# We have given the title to the chart using plt.title()

# plt.show() - To show the chart

# %% [markdown]
# ## Countplot :

# %%
sns.countplot(data = data , x = "international plan", hue = "churn", palette = "rocket")
py.show()

# Drawing a countplot for the column 'international plan' from the dataset using seaborn library...
# ...selecting the Churn column for hue
# 'hue=churn' represents that we want to use column 'churn' for color encoding 
# i.e. color the bars for Churn and Not-Churn differently
# Out:
# <AxesSubplot:xlabel='international plan', ylabel='count'>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 6) Analyzing the "Voice Mail Plan" column :

# %%
data.head()  # To show the top 5 rows from dataset
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# ## Countplot :

# %%
sns.countplot(data = data , x = "voice mail plan", hue = "churn", palette = "rocket_r")
py.title("Voice mail plan VS Churn rate", fontsize = 20)
py.show()

# Drawing a countplot for the column 'voice mail plan' from the dataset using seaborn library...
# ...selecting the 'churn' column for hue ....
# 'hue=churn' represents that we want to use column 'churn' for color encoding
# i.e. color the bars for Churn and Not-Churn differently

# %% [markdown]
# #### crosstab ()

# %%
vmplan = pd.crosstab(data["voice mail plan"] , data["churn"] , margins = True)
vmplan

# Using crosstab function from pandas library to compute a simple cross-tabulation...
# ...of two columns i.e., 'voice mail plan' & 'churn' and saving the output in varibale 'vmplan'
# ... margins=True means - to show the sum of both values in a new column 'All'
# Out:
# churn            False  True   All
# voice mail plan
# no                2008   403  2411
# yes                842    80   922
# All               2850   483  3333

# %% [markdown]
# ### Creating new column :

# %%
vmplan['churn percent'] = vmplan[True] / vmplan['All'] * 100
vmplan

# Creating a new column 'churn percent'- to show the churn percentage of the customers who were using voice mail plan
# Out:
# churn            False  True   All  churn percent
# voice mail plan
# no                2008   403  2411      16.715056
# yes                842    80   922       8.676790
# All               2850   483  3333      14.491449

# %% [markdown]
# #### unique ()

# %%
data["voice mail plan"].unique()   # To show all the unique values of the column 'voice mail plan'
# Out:
# array(['yes', 'no'], dtype=object)

# %% [markdown]
# #### value_counts ()

# %%
data["voice mail plan"].value_counts()
# Out:
# no     2411
# yes     922
# Name: voice mail plan, dtype: int64

# %%
v = data["voice mail plan"].value_counts()
v

# To show the occurance/count of all unique values of the column 'voice mail plan', and saving the output in variable 'v'
# Out:
# no     2411
# yes     922
# Name: voice mail plan, dtype: int64

# %% [markdown]
# ## Creating a Donut Chart of customers count 'having voice mail plan' and 'not having voice mail plan'

# %%
py.pie(v , labels = ["NO","YES"], startangle = 90 , explode = [0 , 0.1],radius = 1.5, autopct = "%1.2f%%",pctdistance = 0.75)

circle = py.Circle((0,0) , 0.5, color = "white")
c = py.gcf()
c.gca().add_artist(circle)
py.title("Percentage of Customers using Voice Mail Plan", fontsize = 18, color = "blue")
py.show()


# Donut chart is a modified Pie chart, with an area from center cut out

#1 First, drawing a pie plot, using Matplotlib library
# The data is taken from the variable 'v' .... labels are given as 'No' & 'Yes' ...
# ... startangle means the angle for slicing, set as 90 ...
# ... shadow is True means it will drop some shadow of the chart ... radius of the circle is set as 1.5 ... 
# ... explode is used to cut the slice out of the figure ... 
# ... autopct is used to show the % on the chart upto required decimal points ...

#2 Second, using plt.Circle...we will create a circle and save it in the variable name 'circle' ...
# ... putting (0,0) by default ... 0.5 is radius of circle ... and color of circle is 'white'
# plt.gcf() is used to get the current figure ... and we are saving it in variable 'c'

#3 Third, we will add the 'circle' at the center of pie chart ... using gca().add_artist()
# We have given the title to the chart using plt.title()
# plt.show() - To show the chart

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 7) Analyzing the "Number Vmail Message" column :

# %%
data.head()  #To show the top 5 records from dataset
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data["number vmail messages"].unique()  # To show the unique values present in the column 'number vmail messages'
# Out:
# array([25, 26,  0, 24, 37, 27, 33, 39, 30, 41, 28, 34, 46, 29, 35, 21, 32,
#        42, 36, 22, 23, 43, 31, 38, 40, 48, 18, 17, 45, 16, 20, 14, 19, 51,
#        15, 11, 12, 47,  8, 44, 49,  4, 10, 13, 50,  9], dtype=int64)

# %%
data["number vmail messages"].nunique()  # To show the count of unique values present in the column 'number vmail messages'
# Out:
# 46

# %%
data["number vmail messages"].value_counts()

# Showing the occurance/count of unique values of the column 'number vmail messages'
# Out:
# 0     2411
# 31      60
# 29      53
# 28      51
# 33      46
# 27      44
# 30      44
# 24      42
# 26      41
# 32      41
# 25      37
# 23      36
# 36      34
# 22      32
# 35      32
# 39      30
# 34      29
# 37      29
# 21      28
# 38      25
# 20      22
# 19      19
# 40      16
# 42      15
# 17      14
# 16      13
# 41      13
# 43       9
# 15       9
# 18       7
# 44       7
# 14       7
# 45       6
# 12       6
# 46       4
# 13       4
# 47       3
# 50       2
# 9        2
# 8        2
# 11       2
# 48       2
# 49       1
# 4        1
# 10       1
# 51       1
# Name: number vmail messages, dtype: int64

# %%
data["number vmail messages"].describe()
# Out:
# count    3333.000000
# mean        8.099010
# std        13.688365
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        20.000000
# max        51.000000
# Name: number vmail messages, dtype: float64

# %% [markdown]
# ## Distribution plot :

# %%
sns.distplot(data["number vmail messages"])

py.show()

# From Seaborn library we are generating a distribution plot for the column 'number vmail messages'

# %% [markdown]
# ## Boxplot :

# %%
sns.boxplot(x='churn', y='number vmail messages', color='violet', meanline=True, showmeans = True, data=data)
                             # creating a box plot for the cdolumn 'number vmail messages' ... grouped by column 'churn'
py.figure(figsize =(5, 5))  # Setting the size of the figure as 5x5, using matplotlib library
py.show()                   # to show the box plot

# In box plot, a box is plotted from Ist quartile to IIIrd quartile
# here, in this boxplot ... we have values from 'churn' column on x-axis and distribution at y-axis ...
# there are no outliers ... the boundaries are at 0 and 51 ... the minimum value is at 0 ...
# the first quartile (25%) is at 0 ... the second quartile (50%) is also at 0 ... 
# the third quartile (75th percentile) is at 20 ... the maximum value is at 51 ...
# color is set as 'violet' ... meanline=True indicates the mean line ... showmeans=True indicates the mean point ...
# sym='r+' to change the symbol to + sign with red color ... data is taken from our original dataframe 'data'

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 8) Analyzing "Customer Service Calls" column :

# %%
data.head()  # To show the top 5 rows of dataset
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data["customer service calls"].unique()

# To show all the unique values of the column 'customer service calls'
# Out:
# array([1, 0, 2, 3, 4, 5, 7, 9, 6, 8], dtype=int64)

# %%
data["customer service calls"].nunique()

# To show the total number of unique values present in column 'customer service calls'
# Out:
# 10

# %%
data["customer service calls"].value_counts()

# To show the count of the unique values of the column 'customer service calls' from original dataframe
# Out:
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 9       2
# 8       2
# Name: customer service calls, dtype: int64

# %%
churn_data = data[data["churn"]]

churn_data     # creating a new dataframe 'churn_data', with the records of all churned customers
# Out:
#      state  account length  area code phone number international plan  \
# 10      IN              65        415     329-6603                 no
# 15      NY             161        415     351-7269                 no
# 21      CO              77        408     393-7984                 no
# 33      AZ              12        408     360-1596                 no
# 41      MD             135        408     383-6029                yes
# ...    ...             ...        ...          ...                ...
# 3301    CA              84        415     417-1488                 no
# 3304    IL              71        510     330-7137                yes
# 3320    GA             122        510     411-5677                yes
# 3322    MD              62        408     409-1856                 no
# 3323    IN             117        415     362-5899                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
churn_data["customer service calls"].value_counts()

# To show the count/occurance of the unique values of the column 'customer service calls'
# Out:
# 1    122
# 0     92
# 2     87
# 4     76
# 3     44
# 5     40
# 6     14
# 7      5
# 9      2
# 8      1
# Name: customer service calls, dtype: int64

# %% [markdown]
# ##### crosstab ()

# %%
cscalls = pd.crosstab(data["customer service calls"] , data["churn"], margins = True)
                # Using crosstab function from pandas library to compute a simple cross-tabulation...
                # ...of two columns i.e., 'customer service calls' & 'churn' and saving the output in varibale 'c'
                # ... margins=True means - to show the sum of both values in a new column 'All'

cscalls["Churn percentage"] = cscalls[True] * 100 / cscalls["All"]
               # Creating a new column 'churn percent', which shows the...
               # ...percentage of churn customers against each count of customer service calls

cscalls
# Out:
# churn                   False  True   All  Churn percentage
# customer service calls
# 0                         605    92   697         13.199426
# 1                        1059   122  1181         10.330229
# 2                         672    87   759         11.462451
# 3                         385    44   429         10.256410
# 4                          90    76   166         45.783133
# 5                          26    40    66         60.606061
# 6                           8    14    22         63.636364
# 7                           4     5     9         55.555556
# 8                           1     1     2         50.000000
# 9                           0     2     2        100.000000
# All                      2850   483  3333         14.491449

# %% [markdown]
# ## Drawing a countplot for the column 'customer service calls' :

# %%
py.figure(figsize = (10,5))
sns.countplot(data = data , x = "customer service calls" , hue = "churn" , palette = "viridis")
py.title("Customer Service Calls VS Churn" , fontsize = 15)
py.legend(title = "Legend" , bbox_to_anchor = (0.90,1))
py.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 9) Analyzing "Per Minute Charge" column :

# %%
data.head()   # To show the top 5 records from dataset
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %% [markdown]
# ### mean ()

# %%
dc_pm = data["total day charge"].mean() / data["total day minutes"].mean()
# Checking per minute day charge

ec_pm = data["total eve charge"].mean() / data["total eve minutes"].mean()
# Checking per minute evening charge

nc_pm = data["total night charge"].mean() / data["total night minutes"].mean()
# Checking per minute night charge

intc_pm = data["total intl charge"].mean() / data["total intl minutes"].mean()
# Checking per minute international charge

# %%
print(f"Per minute day charge is : {dc_pm}")
print()
print(f"per minute evening charge is : {ec_pm}")
print()
print(f"Per minute evening charge is : {nc_pm}")
print()
print(f"Per minute international charge is : {intc_pm}")
# Out:
# Per minute day charge is : 0.1700030073913066
#
# per minute evening charge is : 0.08500104871485774
#
# Per minute evening charge is : 0.04500041448440013
#
# Per minute international charge is : 0.2700500279887098

# %% [markdown]
# ## Barplot :

# %%
py.figure(figsize = (10,4))
sns.barplot(x = ["day" ,"evening","night","international"] , y = [dc_pm , ec_pm , nc_pm , intc_pm])
py.title("Per minute call charges" , fontsize = 18)
py.show()

# drawing a bar plot to represent different 'per minute call chagres'
# on x-axis we have given the naming .... on y-axis we have given the charges
# plt.show() - to show the plot
